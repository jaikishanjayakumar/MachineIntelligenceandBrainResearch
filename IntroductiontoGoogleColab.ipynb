# %% [markdown]
# ![picture](https://drive.google.com/uc?export=view&id=1-HwoOx645-DW51QsJLKE1FzvIXVyKQqj)
#
# #Machine Intelligence and Brain Research
# *Center for Computational Brain Research, Indian institute of Technology Madras*

# %% [markdown]
# # Week 1: Introduction to Google colab

# %% [markdown]
# ##Getting started
# <p> Welcome, this notebook is to get started on google colab. To start working with Colab you first need to log in to your google account, then go to this link (https://colab.research.google.com.)</p>.
#
#
# <p> We will be using python notebooks for most of the tutorials. These notebooks can be created locally in your own machine using tools such as Anaconda, Jupyter, etc. But to make things simpler, we will create and use notebooks directly in google colab.</p>
#
# <p> Google colab will create these notebooks under "Colab notebooks" in your google drive. </p>
#
# <p> The exercises and tutorial notebooks created by us are "read-only" but they can be copied onto your personal notebooks for your use </p>

# %% [markdown]
# ![picture2](https://drive.google.com/uc?export=view&id=1-_Kbrevv-w_i83YRjKeJa-xYyHBw3nfS)

# %% [markdown]
# ##Creating new notebooks
#  You can create your own notebook which will default to Untited.ipynb

# %% [markdown]
# ![picture1](https://drive.google.com/uc?export=view&id=1-Uwxw9RSkUFBRoNNpp0d79v9mXuykSvI)

# %% [markdown]
# ## Environment
#
# We will be using the default python3 program. You can also create GPU/TPU versions of the python program

# %% [markdown]
# ## The next notebook is the Week1 Introduction to Python notebook
